# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/mnt/c/Users/andre/OneDrive/Escritorio/PROYECTOS ANALIS DE DATOS/2.ANALIS DE DATOS/informacion/mission_launches.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 2             2           2       SpaceX
# 3             3           3    Roscosmos
# 4             4           4          ULA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                          Date                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# ...

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 2             2           2       SpaceX
# 3             3           3    Roscosmos
# 4             4           4          ULA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                          Date                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# ...

# %%
df1.drop(['Unnamed: 0.1','Unnamed: 0'], axis=1, inplace=True )

# %%
df1
# Out:
#      Organisation                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %% [markdown]
# ### Extraccion del año

# %%
df1['Año'] = df1['Date'].str.split().str[3]

# %%
df1
# Out:
#      Organisation                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %% [markdown]
# ### ¿Qué organización lanzó más misiones espaciales en un año determinado?

# %%
df1['Empresa y año de lazamiento'] = df1['Organisation'].str.cat(df1['Año'], sep=', ')

# %%
df1
# Out:
#      Organisation                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
df1['Empresa y año de lazamiento'].max()
# Out:
# 'i-Space, 2019'

# %% [markdown]
# ### ¿Cuántos lanzamientos se realizaron por año?

# %%
numero_de_lazamientos_por_años = df1['Año']. value_counts()
print(numero_de_lazamientos_por_años)
# Out:
# Año
# 1971    119
# 2018    117
# 1977    114
# 1975    113
# 1976    113
#        ...
# 2005     37
# 2010     37
# 1958     28
# 1959     20
# 1957      3
# Name: count, Length: 64, dtype: int64

# %% [markdown]
# ### ¿Cómo ha variado el costo de una misión espacial a lo largo del tiempo?

# %% [markdown]
# convertimos los NaN de la columna PRICE en valores con cero

# %%
df1['Price'] = df1['Price'].fillna(0)

# %% [markdown]
# Creamos una copia con los cambios realizados

# %%
df2= df1.copy()

# %%
df2
# Out:
#      Organisation                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
df2['Price'] = df2['Price'].astype(str).str[:2]

# %%
df2['Price'] = pd.to_numeric(df2['Price'], errors='coerce')

# %% [markdown]
# Valores que son elevados a la potencia de 10

# %% [markdown]
# Media

# %%
df2.Price.mean()
# Out:
# np.float64(8.618705035971223)

# %% [markdown]
# Mediana

# %%
df2.Price.median()
# Out:
# np.float64(0.0)

# %%
df2.Price.max()
# Out:
# np.float64(90.0)

# %%
df2.Price.min()
# Out:
# np.float64(0.0)

# %% [markdown]
# ### ¿Qué meses son los más populares para los lanzamientos?

# %% [markdown]
# Extraccion del mes

# %%
df2['Mes'] = df2['Date'].str.split().str[1]

# %%
df2
# Out:
#      Organisation                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
df2.Mes.max()
# Out:
# 'Sep'

# %% [markdown]
# El mes mas popular para realizar lanzamientos es: Septiembre

# %% [markdown]
# ### ¿Se han vuelto más seguras las misiones espaciales o las posibilidades de fracaso se han mantenido sin cambios?

# %% [markdown]
# Las misiones se han vuelto mas seguras

# %%
df2.Mission_Status.max()
# Out:
# 'Success'
